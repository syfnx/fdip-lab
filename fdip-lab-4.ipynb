# %% [markdown]
# # Practical 4
#
# Name: Madhav Jha <br>
# Roll no.: 48 <br>
# Batch: E3 <br>
# Branch: CSE(AIML) <br>
# Semester: VI

# %% [markdown]
# ### AIM: To study and perform Histogram processing in image enhancement.
# 1. Plot a Histogram of Grayscale and Color Image
# 2. Contrast and Brightness stretching of Grayscale image
# 3. Perform Histogram Equalization on Grayscale image

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

# %%
folder = "/content/drive/MyDrive/Colab Notebooks/img/"

# %%
# 1. Plot a Histogram of Grayscale and Color Image

img1 = cv2.imread(folder + "lenna.png", 1)
img2 = cv2.imread(folder + "lenna.png", 0)

print("Color image: ")
cv2_imshow(img1)

histogram1 = cv2.calcHist([img1], [0], None, [256], [0, 256])
plt.title("Color Image")
plt.xlabel("Bins")
plt.ylabel("No. of pixels")
plt.plot(histogram1)
plt.show()

print("Gray image: ")
cv2_imshow(img2)

histogram2 = cv2.calcHist([img2], [0], None, [256], [0, 256])
plt.title("Grey Image")
plt.xlabel("Bins")
plt.ylabel("No. of pixels")
plt.plot(histogram2)
plt.show()
# Out:
# Color image:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3206DD1D90>
# Gray image:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F3206DB39D0>

# %%
# 2. Contrast and Brightness stretching of Grayscale image

img = cv2.imread(folder + "map.jpg", 1)

norm_img = cv2.normalize(img, None, alpha=0, beta=1.2, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

# scale to uint8
# norm_img = np.clip(norm_img, 0, 1)
norm_img = (255*norm_img).astype(np.uint8)

# display input and both output images
print("Image: ")
cv2_imshow(img)

print("Stretching: ")
cv2_imshow(norm_img)
# Out:
# Image:
# <PIL.Image.Image image mode=RGB size=520x517 at 0x7F3206DD1C40>
# Stretching:
# <PIL.Image.Image image mode=RGB size=520x517 at 0x7F3206DD1C40>

# %%
# 3. Perform Histogram Equalization on Grayscale image

img1 = cv2.imread(folder + "lenna.png", 0)

print("Image: ")
cv2_imshow(img1)

histogram1 = cv2.equalizeHist(img1)
plt.title("Equalize Histogram: ")
plt.xlabel("Bins")
plt.ylabel("No. of pixels")
plt.plot(histogram1)
plt.show()
# Out:
# Image:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F3206DD3820>
